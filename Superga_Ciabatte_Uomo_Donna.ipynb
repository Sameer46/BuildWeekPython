# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def estrai_dati(url, categoria):
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Errore nella richiesta HTTP: {response.status_code}")
        return []
    
    soup = BeautifulSoup(response.content, 'html.parser')
    
    prodotti = []
    for item in soup.select('.grid__item'):
        nome_elem = item.select_one('.grid-product__title--heading')
        prezzo_elem = item.select_one('custom-price')
        colore_elem = item.select_one('.cb-italic')
        
        nome = nome_elem.text.strip() if nome_elem else 'Nome non disponibile'
        prezzo_text = prezzo_elem.text.strip() if prezzo_elem else '0'
        
        # Pulizia testo
        prezzo = prezzo_text.replace('da', '').replace('€', '').replace('\n', '').replace(' ', '').replace(',', '.')
        try:
            prezzo = float(prezzo) if prezzo else 0.0
        except ValueError:
            print(f"Errore di conversione per il prezzo: {prezzo_text}")
            prezzo = 0.0
        
        colore = colore_elem.text.strip() if colore_elem else 'Non specificato'
        
        prodotti.append([nome, prezzo, categoria, colore])
    
    return prodotti

# URL della categoria ciabatte donna Primavera Estate su Superga
url_ciabatte_donna = "https://www.superga.com/it/collections/ciabatte-donna"
# URL della categoria ciabatte uomo Primavera Estate su Superga
url_ciabatte_uomo = "https://www.superga.com/it/collections/ciabatte-uomo"
# Raccogli i dati per la categoria "Ciabatte Donna"
dati_ciabatte_donna = estrai_dati(url_ciabatte_donna, 'Ciabatte Donna')

# Raccogli i dati per la categoria "Ciabatte Uomo"
dati_ciabatte_uomo = estrai_dati(url_ciabatte_uomo, 'Ciabatte Uomo')

# Crea un DataFrame unificato
dati_totali = pd.DataFrame(dati_ciabatte_donna + dati_ciabatte_uomo, columns=['Nome', 'Prezzo', 'Categoria', 'Colore'])
print(dati_totali.to_string(index=False))
dati_totali.to_csv('dati_ciabatte_primavera_estate_superga.csv', index=False)
# Out:
#                                                Nome  Prezzo      Categoria                    Colore
#                                Nome non disponibile     0.0 Ciabatte Donna           Non specificato
#                                Nome non disponibile     0.0 Ciabatte Donna           Non specificato
#                                Nome non disponibile     0.0 Ciabatte Donna           Non specificato
#                                Nome non disponibile     0.0 Ciabatte Donna           Non specificato
#                                Nome non disponibile     0.0 Ciabatte Donna           Non specificato
#                                Nome non disponibile     0.0 Ciabatte Donna           Non specificato
#                                Nome non disponibile     0.0 Ciabatte Donna           Non specificato
#                                Nome non disponibile     0.0 Ciabatte Donna           Non specificato
#                                Nome non disponibile     0.0 Ciabatte Donna           Non specificato
#                                Nome non disponibile     0.0 Ciabatte Donna           Non specificato
#                                Nome non disponibile     0.0 Ciabatte Donna           Non specificato
#                                Nome non disponibile     0.0 Ciabatte Donna           Non specificato
#                                Nome non disponibile     0.0 Ciabatte Donna           Non specificato
#                                Nome non disponibile     0.0 Ciabatte Donna           Non specificato
#                                Nome non disponibile     0.0 Ciabatte Donna           Non specificato
#                                Nome non disponibile     0.0 Ciabatte Donna           Non specificato
#                                Nome non disponibile     0.0 Ciabatte Donna           Non specificato
#                                Nome non disponibile     0.0 Ciabatte Donna           Non specificato
#                                Nome non disponibile     0.0 Ciabatte Donna           Non specificato
#                     1908 SLIDES CLEAR IDENTITYBLACK    35.0 Ciabatte Donna                     BLACK
#                     1908 SLIDES CLEAR IDENTITYBLACK    35.0 Ciabatte Donna                     BLACK
#              1908 SLIDES CLEAR IDENTITYPINK TICKLED    35.0 Ciabatte Donna              PINK TICKLED
#                     1908 SLIDES POLYSOFTWHITE-BLACK    29.0 Ciabatte Donna               WHITE-BLACK
#                     1908 SLIDES POLYSOFTBLACK-WHITE    29.0 Ciabatte Donna               BLACK-WHITE
#                 1908 SLIDES POLYSOFTBLUE NAVY-WHITE    29.0 Ciabatte Donna           BLUE NAVY-WHITE
#                    1908 SLIDES POLYSOFTPINK PARFAIT    29.0 Ciabatte Donna              PINK PARFAIT
#                1908 SLIDES POLYSOFTWHITE-MULTICOLOR    29.0 Ciabatte Donna          WHITE-MULTICOLOR
#                       1908 SLIDES POLYSOFTAZURE ICE    29.0 Ciabatte Donna                 AZURE ICE
#          1908 SLIDES POLYSOFTORANGE MELON-ORANGE MD    29.0 Ciabatte Donna    ORANGE MELON-ORANGE MD
#                       1908 SLIDES POLYSOFTWHITE-RED    29.0 Ciabatte Donna                 WHITE-RED
# 1908 SLIDES CLEAR IDENTITYWHITE AVORIO-VIOLET LILLA    35.0 Ciabatte Donna WHITE AVORIO-VIOLET LILLA
#   1908 SLIDES CURLY PADDED STRIPESWHITE-SHADED PINK    45.0 Ciabatte Donna         WHITE-SHADED PINK
#                                Nome non disponibile     0.0 Ciabatte Donna           Non specificato
#                                Nome non disponibile     0.0 Ciabatte Donna           Non specificato
#                                Nome non disponibile     0.0 Ciabatte Donna           Non specificato
#                                Nome non disponibile     0.0  Ciabatte Uomo           Non specificato
#                                Nome non disponibile     0.0  Ciabatte Uomo           Non specificato
#                                Nome non disponibile     0.0  Ciabatte Uomo           Non specificato
#                                Nome non disponibile     0.0  Ciabatte Uomo           Non specificato
#                                Nome non disponibile     0.0  Ciabatte Uomo           Non specificato
#                                Nome non disponibile     0.0  Ciabatte Uomo           Non specificato
#                                Nome non disponibile     0.0  Ciabatte Uomo           Non specificato
#                                Nome non disponibile     0.0  Ciabatte Uomo           Non specificato
#                                Nome non disponibile     0.0  Ciabatte Uomo           Non specificato
#                                Nome non disponibile     0.0  Ciabatte Uomo           Non specificato
#                                Nome non disponibile     0.0  Ciabatte Uomo           Non specificato
#                                Nome non disponibile     0.0  Ciabatte Uomo           Non specificato
#                                Nome non disponibile     0.0  Ciabatte Uomo           Non specificato
#                                Nome non disponibile     0.0  Ciabatte Uomo           Non specificato
#                                Nome non disponibile     0.0  Ciabatte Uomo           Non specificato
#                                Nome non disponibile     0.0  Ciabatte Uomo           Non specificato
#                                Nome non disponibile     0.0  Ciabatte Uomo           Non specificato
#                                Nome non disponibile     0.0  Ciabatte Uomo           Non specificato
#                                Nome non disponibile     0.0  Ciabatte Uomo           Non specificato
#                     1908 SLIDES POLYSOFTBLACK-WHITE    29.0  Ciabatte Uomo               BLACK-WHITE
#                     1908 SLIDES POLYSOFTBLACK-WHITE    29.0  Ciabatte Uomo               BLACK-WHITE
#                     1908 SLIDES POLYSOFTWHITE-BLACK    29.0  Ciabatte Uomo               WHITE-BLACK
#                     1908 SLIDES CLEAR IDENTITYBLACK    35.0  Ciabatte Uomo                     BLACK
#              1908 SLIDES CLEAR IDENTITYPINK TICKLED    35.0  Ciabatte Uomo              PINK TICKLED
#                 1908 SLIDES POLYSOFTBLUE NAVY-WHITE    29.0  Ciabatte Uomo           BLUE NAVY-WHITE
#                    1908 SLIDES POLYSOFTPINK PARFAIT    29.0  Ciabatte Uomo              PINK PARFAIT
#                1908 SLIDES POLYSOFTWHITE-MULTICOLOR    29.0  Ciabatte Uomo          WHITE-MULTICOLOR
#                       1908 SLIDES POLYSOFTAZURE ICE    29.0  Ciabatte Uomo                 AZURE ICE
#          1908 SLIDES POLYSOFTORANGE MELON-ORANGE MD    29.0  Ciabatte Uomo    ORANGE MELON-ORANGE MD
#                       1908 SLIDES POLYSOFTWHITE-RED    29.0  Ciabatte Uomo                 WHITE-RED
# 1908 SLIDES CLEAR IDENTITYWHITE AVORIO-VIOLET LILLA    35.0  Ciabatte Uomo WHITE AVORIO-VIOLET LILLA
#                                Nome non disponibile     0.0  Ciabatte Uomo           Non specificato
#                                Nome non disponibile     0.0  Ciabatte Uomo           Non specificato
#                                Nome non disponibile     0.0  Ciabatte Uomo           Non specificato
